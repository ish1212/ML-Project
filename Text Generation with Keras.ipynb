# %%
import numpy
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils

# %%
# load ascii text and covert to lowercase
with open('alice.txt', 'r', encoding='utf-8') as fp:
    txt = fp.read()

raw_text = txt
raw_text = raw_text.lower()

# %%
# create mapping of unique chars to integers
chars = sorted(list(set(raw_text)))
char_to_int = dict((c, i) for i, c in enumerate(chars))

# %%
n_chars = len(raw_text)
n_vocab = len(chars)
print("Total Characters: %s "% n_chars)
print("Total Vocab: %s"% n_vocab)
# Out:
# Total Characters: 163781
# Total Vocab: 59

# %%
# prepare the dataset of input to output pairs encoded as integers
seq_length = 100
dataX = []
dataY = []
for i in range(0, n_chars - seq_length, 1):
    seq_in = raw_text[i:i + seq_length]
    seq_out = raw_text[i + seq_length]
    dataX.append([char_to_int[char] for char in seq_in])
    dataY.append(char_to_int[seq_out])
n_patterns = len(dataX)
print("Total Patterns: %s"% n_patterns)
# Out:
# Total Patterns: 163681

# %%
# reshape X to be [samples, time steps, features]
X = numpy.reshape(dataX, (n_patterns, seq_length, 1))
# normalize
X = X / float(n_vocab)
# one hot encode the output variable
y = np_utils.to_categorical(dataY)

# %%
# define the LSTM model
model = Sequential()
model.add(LSTM(256, input_shape=(X.shape[1], X.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
# define the checkpoint
filepath="weights-improvement-{epoch:02d}-{loss:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

# %%
model.fit(X, y, epochs=20, batch_size=128, callbacks=callbacks_list)
# Out:
# Epoch 1/20
#   8576/163681 [>.............................] - ETA: 12:18 - loss: 3.2109
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-c76b741c7de3> in <module>()
# ----> 1 model.fit(X, y, epochs=20, batch_size=128, callbacks=callbacks_list)
#
# /home/krohak/anaconda3/lib/python3.6/site-packages/keras/models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1000                               initial_epoch=initial_epoch,
#    1001                               steps_per_epoch=steps_per_epoch,
# -> 1002                               validation_steps=validation_steps)
#    1003
#    1004     def evaluate(self, x=None, y=None,
#
# /home/krohak/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# /home/krohak/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1234                         ins_batch[i] = ins_batch[i].toarray()
#    1235
# -> 1236                     outs = f(ins_batch)
#    1237                     if not isinstance(outs, list):
#    1238                         outs = [outs]
#
# /home/krohak/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2480         session = get_session()
#    2481         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2482                               **self.session_kwargs)
#    2483         return updated[:len(self.outputs)]
#    2484
#
# /home/krohak/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/krohak/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# /home/krohak/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /home/krohak/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# /home/krohak/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# /home/krohak/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:

# %%
# load the network weights
filename = "weights-improvement-19-1.9435.hdf5"
model.load_weights(filename)
model.compile(loss='categorical_crossentropy', optimizer='adam')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-19-265f1efe0e22> in <module>()
#       1 # load the network weights
#       2 filename = "weights-improvement-19-1.9435.hdf5"
# ----> 3 model.load_weights(filename)
#       4 model.compile(loss='categorical_crossentropy', optimizer='adam')
#
# /home/krohak/anaconda3/lib/python3.6/site-packages/keras/models.py in load_weights(self, filepath, by_name, skip_mismatch, reshape)
#     752         if h5py is None:
#     753             raise ImportError('`load_weights` requires h5py.')
# --> 754         with h5py.File(filepath, mode='r') as f:
#     755             if 'layer_names' not in f.attrs and 'model_weights' in f:
#     756                 f = f['model_weights']
#
# /home/krohak/anaconda3/lib/python3.6/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     269
#     270                 fapl = make_fapl(driver, libver, **kwds)
# --> 271                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#     272
#     273                 if swmr_support:
#
# /home/krohak/anaconda3/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#      99         if swmr and swmr_support:
#     100             flags |= h5f.ACC_SWMR_READ
# --> 101         fid = h5f.open(name, flags, fapl=fapl)
#     102     elif mode == 'r+':
#     103         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/home/ilan/minonda/conda-bld/h5py_1496889914775/work/h5py/_objects.c:2846)()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/home/ilan/minonda/conda-bld/h5py_1496889914775/work/h5py/_objects.c:2804)()
#
# h5py/h5f.pyx in h5py.h5f.open (/home/ilan/minonda/conda-bld/h5py_1496889914775/work/h5py/h5f.c:2123)()
#
# OSError: Unable to open file (Unable to open file: name = 'weights-improvement-19-1.9435.hdf5', errno = 2, error message = 'no such file or directory', flags = 0, o_flags = 0)

# %%
int_to_char = dict((i, c) for i, c in enumerate(chars))

# %%
# pick a random seed
start = numpy.random.randint(0, len(dataX)-1)
pattern = dataX[start]
print "Seed:"
print "\"", ''.join([int_to_char[value] for value in pattern]), "\""
# generate characters
for i in range(1000):
    x = numpy.reshape(pattern, (1, len(pattern), 1))
    x = x / float(n_vocab)
    prediction = model.predict(x, verbose=0)
    index = numpy.argmax(prediction)
    result = int_to_char[index]
    seq_in = [int_to_char[value] for value in pattern]
    sys.stdout.write(result)
    pattern.append(index)
    pattern = pattern[1:len(pattern)]
print "\nDone."
# Out:
#   File "<ipython-input-21-37b89d60f6d6>", line 4
#     print "Seed:"
#                 ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
# Larger LSTM Network to Generate Text for Alice in Wonderland
import numpy
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils
# load ascii text and covert to lowercase
filename = "wonderland.txt"
raw_text = open(filename).read()
raw_text = raw_text.lower()
# create mapping of unique chars to integers
chars = sorted(list(set(raw_text)))
char_to_int = dict((c, i) for i, c in enumerate(chars))
# summarize the loaded data
n_chars = len(raw_text)
n_vocab = len(chars)
print "Total Characters: ", n_chars
print "Total Vocab: ", n_vocab
# prepare the dataset of input to output pairs encoded as integers
seq_length = 100
dataX = []
dataY = []
for i in range(0, n_chars - seq_length, 1):
	seq_in = raw_text[i:i + seq_length]
	seq_out = raw_text[i + seq_length]
	dataX.append([char_to_int[char] for char in seq_in])
	dataY.append(char_to_int[seq_out])
n_patterns = len(dataX)
print "Total Patterns: ", n_patterns
# reshape X to be [samples, time steps, features]
X = numpy.reshape(dataX, (n_patterns, seq_length, 1))
# normalize
X = X / float(n_vocab)
# one hot encode the output variable
y = np_utils.to_categorical(dataY)
# define the LSTM model
model = Sequential()
model.add(LSTM(256, input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(256))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam')
# define the checkpoint
filepath="weights-improvement-{epoch:02d}-{loss:.4f}-bigger.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]
# fit the model
model.fit(X, y, epochs=50, batch_size=64, callbacks=callbacks_list)
# Out:
#   File "<ipython-input-22-a2e3f081ed56>", line 19
#     print "Total Characters: ", n_chars
#                              ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
# Load Larger LSTM network and generate text
import sys
import numpy
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils
# load ascii text and covert to lowercase
filename = "wonderland.txt"
raw_text = open(filename).read()
raw_text = raw_text.lower()
# create mapping of unique chars to integers, and a reverse mapping
chars = sorted(list(set(raw_text)))
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars))
# summarize the loaded data
n_chars = len(raw_text)
n_vocab = len(chars)
print "Total Characters: ", n_chars
print "Total Vocab: ", n_vocab
# prepare the dataset of input to output pairs encoded as integers
seq_length = 100
dataX = []
dataY = []
for i in range(0, n_chars - seq_length, 1):
	seq_in = raw_text[i:i + seq_length]
	seq_out = raw_text[i + seq_length]
	dataX.append([char_to_int[char] for char in seq_in])
	dataY.append(char_to_int[seq_out])
n_patterns = len(dataX)
print "Total Patterns: ", n_patterns
# reshape X to be [samples, time steps, features]
X = numpy.reshape(dataX, (n_patterns, seq_length, 1))
# normalize
X = X / float(n_vocab)
# one hot encode the output variable
y = np_utils.to_categorical(dataY)
# define the LSTM model
model = Sequential()
model.add(LSTM(256, input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(256))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))
# load the network weights
filename = "weights-improvement-47-1.2219-bigger.hdf5"
model.load_weights(filename)
model.compile(loss='categorical_crossentropy', optimizer='adam')
# pick a random seed
start = numpy.random.randint(0, len(dataX)-1)
pattern = dataX[start]
print "Seed:"
print "\"", ''.join([int_to_char[value] for value in pattern]), "\""
# generate characters
for i in range(1000):
	x = numpy.reshape(pattern, (1, len(pattern), 1))
	x = x / float(n_vocab)
	prediction = model.predict(x, verbose=0)
	index = numpy.argmax(prediction)
	result = int_to_char[index]
	seq_in = [int_to_char[value] for value in pattern]
	sys.stdout.write(result)
	pattern.append(index)
	pattern = pattern[1:len(pattern)]
print "\nDone."
# Out:
#   File "<ipython-input-23-943ee6c7a1b2>", line 21
#     print "Total Characters: ", n_chars
#                              ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
'''Example script to generate text from Nietzsche's writings.

At least 20 epochs are required before the generated text
starts sounding coherent.

It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.

If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
'''

from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io

path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower()
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1


# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, logs):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=60,
          callbacks=[print_callback])
# Out:
# Using TensorFlow backend.
# corpus length: 600893
# total chars: 57
# nb sequences: 200285
# Vectorization...
# Build model...
# Epoch 1/60
# 200285/200285 [==============================] - 187s 934us/step - loss: 2.0006
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "out question, and also without conscious"
# out question, and also without conscious of the light of the stronger to the stronger to the pregent of the prevert of the most to a present and the power the stronged and the self to the probection of the prevert to accusted and the present to where the strongent of strongerity and institual of the prevert of the strong the streng of the present of the most and the precestion of the precisely in the persent of the probect of the strong
# ----- diversity: 0.5
# ----- Generating with seed: "out question, and also without conscious"
# out question, and also without conscious of a conception of his inceveltion of one pregent where with where "the bett to be the history the errom of good with we every for the state and spoin and strong in the moral and the scholing to decient and consequeally and every the self referian believe the world an exalther of the has one ade of the state of man an and with self, and the lofe, which itself an one the very to the instance of th
# ----- diversity: 1.0
# ----- Generating with seed: "out question, and also without conscious"
# out question, and also without consciousned betbey
# a pernemule aponge: -that esirned usiture. the statretine lecce, as teathe powish--at as shatt of meanve doust; and condect because in
# even
# 2ugarly satire is as the give.
# nexurably accunition of "the eoverkatirial computhy" of the exmeen to weasher of mase.=--than
# so fitt the
# people to farre persess knoungehs. is that the some sus isily elountly, hadvers sequined feershing a prounsure
# ----- diversity: 1.2
# ----- Generating with seed: "out question, and also without conscious"
# out question, and also without conscious relieve of actiret, the
# facte (t pla  s
# will,
# him by gid. auramnes, it world, asureifect and voltty noed unverute an a some weo, weariating-
# emal riacusteste: lardeen way penpestili, neptioustly howe, and. the hispostarie, diess and ieknerse evapsion:
# to encehably whe h modencally than retens' the licks that fic chomen to precatione. "ulvorain usobess allow the conselt of
# perputhever tade conf,"
#
# Epoch 2/60
# 200285/200285 [==============================] - 178s 887us/step - loss: 1.6387
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: " permanently useful; when he has,
# theref"
#  permanently useful; when he has,
# therefore of the strength to the preving and the soul to the strength of the sentiment and the strength of them and them and the proper of the sentiment of the sentiment of the sentiment the sentent of the sentiment of the present of the sentiment of the sentiment of the sentiment of the preving and the sentiment of the sented of the prepling of the free of the master to the sentiment of the happiness o
# ----- diversity: 0.5
# ----- Generating with seed: " permanently useful; when he has,
# theref"
#  permanently useful; when he has,
# therefore and every according of the reble of the perpodual soul
# its putent of the personal propent, and seem of this mankind of are of the forme soul, and the understand to the stand and of the tenced to the convented to himself and in them strength and in the and of all the concean and in the superfrient of the previement to them an action of a simplation of so read to the bettance of the best himself
# ----- diversity: 1.0
# ----- Generating with seed: " permanently useful; when he has,
# theref"
#  permanently useful; when he has,
# therefachying plopt of srake enfecting subjiction great see with outian in
# to goodne: for the
# strendth
# band in the psispicatount and corcoused (when uphe, porting" which, he
# fremgs of swoengher, and conscuution, as their mode one forgine to taste act if eye behigct.--them
# -meof to hore philosophers axd indeserptimation and
# fausesed.=--things to womkness unto such use his gretts of heludgeh, is flee to
# i
# ----- diversity: 1.2
# ----- Generating with seed: " permanently useful; when he has,
# theref"
#  permanently useful; when he has,
# therefore yea not
# one ones pains of indiment
# not a cholzgensed, time gexhant oc cas its gree world, thay atal having lon wathess.k
# now last
# are as the foltestaality aspuringer",
# one and in a
# you beheen's as wells, of arrentle, aren,
# who, child, a khenoiouse take we go the seviee an wurg concerns, is rucation yrem have in
# prases, as thusychowe--of also uperhass. "astention-a refrestionles
# of huselingt:
# Epoch 3/60
# 200285/200285 [==============================] - 178s 888us/step - loss: 1.5454
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "ce all evil is done
# unwittingly. the evi"
# ce all evil is done
# unwittingly. the evil as the conscious the sense of the morality of the sense of the sense of the developed and the master and in the present of the conscious of the sense of the speaks as the spiritually the sense of the conscious that there is the sense of the spiritudes of the sense of the sense of the sense of the world, and it is the sense of the sense of the sense of the sense of the spiritudes of the sense of
# ----- diversity: 0.5
# ----- Generating with seed: "ce all evil is done
# unwittingly. the evi"
# ce all evil is done
# unwittingly. the evil of the sense of constrait of the present of the spirit of the living that the ulmbort conscious and the soul experiences of the mest fact, schopenhauer and the developed certain the spiritude in the sense as a psichon experiences and respect and himself as it merely the coment of the sensence that is sery and only this is the sererative as there is the good existence of the later of the belief o
# ----- diversity: 1.0
# ----- Generating with seed: "ce all evil is done
# unwittingly. the evi"
# ce all evil is done
# unwittingly. the evilrodiousulatists that
# obediness of
# "kund it obedred.
# mostivulor,--such doubtranged it not know counse, most necessous:ed wemen has desiim not the problem-suportional friencens?" quitly hores! yet nothing must
# outen and spiritules, food sorrais, og the belies, that in stoix!
# perhangy own question; leavesty as which one, there is indicniffelanguais, and state there is
# is be only malways thinker outc
# ----- diversity: 1.2
# ----- Generating with seed: "ce all evil is done
# unwittingly. the evi"
# ce all evil is done
# unwittingly. the evilrous evil 'ngeish, would
# displete dys can abover.
#
# 2gain jod, psysuhow a rewavible, unoulsugatultochagesishing as he as enjoyoe,
# repestedd unbymoin, anthurnate let
# ficts philosophic dmenle! to whicy i beyond of ithadotual as far one within inless that it fleman must
# crarless!l
# a
# mor; myfuedg were enjoyse) quit=-grelate all theerward deviced is, prorpereruliness. "this-" and
# sitsed by a hal puctle
# Epoch 4/60
# 200285/200285 [==============================] - 180s 900us/step - loss: 1.4994
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "d
# insists on taking things profoundly, v"
# d
# insists on taking things profoundly, viction of the subject of the moral in the some the some the deperious and the some that it is the most the some the something of the sensation of the subject of the thing of the thing of the some the problems of the problem of the something of the serve the same the moral and the experience of the sensation of the some the some the thing of the individual to the some the some the thing of the some
# ----- diversity: 0.5
# ----- Generating with seed: "d
# insists on taking things profoundly, v"
# d
# insists on taking things profoundly, vanity in the streat the love the something of the sole, that they may in himself to the stands there is probest any consers and pain of the such have and something it has delical the man of god the showly only of himself any be one and to some something in itself even all the fact of the deceived of the development in all surmon, the speaks for the some are
# man of where the moral some the regards
# ----- diversity: 1.0
# ----- Generating with seed: "d
# insists on taking things profoundly, v"
# d
# insists on taking things profoundly, vigoration (as one that i was mean exalter contrain, all i
# kind with what it comest only do unachages thosyearny! our that contoture see of all a nature from agains and
# is the weak, toy they the
# "no vight, that is
# need and justs us the finger could furth: the word and individual sub? men than sensth individual
# moying
# low ones ifed conceptionap of all feels or influence and diffined its difficult es
# ----- diversity: 1.2
# ----- Generating with seed: "d
# insists on taking things profoundly, v"
# d
# insists on taking things profoundly, valitians himperpotion! "i
# lever,"
# )way,
# sly typecce to huppositioned wonder to despaditof"sfiourtd explaine, need
# religion, henkeremy
# probably k
# intxonimon of just he masiererve any cieativationi; no
# understhy "tod; hey while how other.s--they for plati live gradually tastert--through ar-serscientue
# of angiefge binishphing is staar to mankind fund anyallhes, whiliselksiaiesk, such alwayseve--prega
# Epoch 5/60
# 200285/200285 [==============================] - 206s 1ms/step - loss: 1.4697
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "lity," against such a "should
# be," howev"
# lity," against such a "should
# be," however, and the conscience of the lover of the most influence of the contradict of the fact of the soul of the process of the great something the most true and the soul of the most desire of the conscience of the present the present of the conscious and in the soul of the most the fact of the most and the soul of the problems of the more and father the problems and the presented and something the and
# ----- diversity: 0.5
# ----- Generating with seed: "lity," against such a "should
# be," howev"
# lity," against such a "should
# be," however, and suprescerned and the tend of all the subjecting and the compulse the and the german things, and something the decain of a long wrong the freedoms, that is every man if all the belief the portrant, have an all the most loved to the way to be heavt a his will and the conscience and sense and the partuling, and suffering the more in here and something with the aspention to the great here and
# ----- diversity: 1.0
# ----- Generating with seed: "lity," against such a "should
# be," howev"
# lity," against such a "should
# be," however.--when they inspoin esent manyurestr-oze
# home
# and recomsers sometime not reed, with immense econem--and arisportting in which yet test flountle than men, the "namely in hanneates and
# neveristince should necessary of the tinect, and was and
# gond
# necessary live--for than of imanilaring presinterive creature to the philosopher the troo wantspect"wies
# not metaphystan that above a "physiale one sou
# ----- diversity: 1.2
# ----- Generating with seed: "lity," against such a "should
# be," howev"
# lity," against such a "should
# be," however,
# i as undled
# which the world seaks, nest can be himdeduch, by true. there is our "goodward the were let detiest be htactors and
# christion an the fact thou
# rordse, so acrased moral,--and luty poctuingble--than thot if theseok thoune is feel doubelical often
# is once will faverary of man our "been dip          xed explase another, he thrays of an all him. and tuwn working, at a troa obligant wink;
# Epoch 6/60
# 200285/200285 [==============================] - 185s 924us/step - loss: 1.4487
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "ent, doubt, and
# tentativeness; the best "
# ent, doubt, and
# tentativeness; the best is a strength of the self-great the the self-great the order to the self-greatest and as a self-great the self-greatest and feeling of the stand and the self-consist as in the world of the world of the world of the world of the self-are the self-greatest the subjection of the the world of the soul of the subjection of the world of the subjection of the fact of the world of the world of the self-co
# ----- diversity: 0.5
# ----- Generating with seed: "ent, doubt, and
# tentativeness; the best "
# ent, doubt, and
# tentativeness; the best to herself in the self-considerion of the "beets and aspection in a contractien,
# and the will in the present of siscentiles of the theistors, and the self-despinie the opposite to as is the
# things of the soul of the smoll the loves the appear and wand influence is the present of means of the thing to a present into his
# self-gregation
# in the prosent of the contemplation of his present and prey the
# ----- diversity: 1.0
# ----- Generating with seed: "ent, doubt, and
# tentativeness; the best "
# ent, doubt, and
# tentativeness; the best bad itedity,
# himhe-inne" first of
# virtuerists and everyance perisre (is invery because the epide" lightrury of it had
# according tto these the herianity
# we dirianly at the time", fineg, is schopeal.tucesipus of efurnate whatever
# france of dogacing has to a pro-the why becoming in suckes and conceuled were stand deeds aest of when self
# manifeles error to wholl
# from while his is round--bestaits; part
# ----- diversity: 1.2
# ----- Generating with seed: "ent, doubt, and
# tentativeness; the best "
# ent, doubt, and
# tentativeness; the best be inlively is indication the very formation plened, shet of hurday stansrating althth
# is the wise, ideasvation to good.
# nek is partod which is nimidudus, ans masberts
# philosopher in their cinm!
#
#
# 101
#
# =this
# hobure-what--seentable" who crequacial extents hold
# as be incimets of the jew sensation licion of knowsoustur give as were o
# uncerouds, he dimplanized, to the
# forthuroned aristaferer and dange
# Epoch 7/60
# 200285/200285 [==============================] - 167s 834us/step - loss: 1.4324
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "no one needs "rights"
# any longer); at on"
# no one needs "rights"
# any longer); at once the world and a constitution of the power and superstition of the subject of the sense of the strength o
# /home/krohak/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:68: RuntimeWarning: divide by zero encountered in log
# f the sense of the subject of the act that the stand the constitution of the strength of the stand and the stand and a ready that the most man which it is a thing of the fact that the subject of the sense of the stand and in the sense of the stand the sense of the stand and as the stand the s
# ----- diversity: 0.5
# ----- Generating with seed: "no one needs "rights"
# any longer); at on"
# no one needs "rights"
# any longer); at one it was still it will the truth of the christianity of the stand a strides of the most manning of conception of the crust the more crueted in the human of the idealimation for the individual intention of all the world, a morals our stand and former faith with which it is the suffering and faoling and self-destrivition of a string the reason in the sensation of the case a itself not be astinction
# ----- diversity: 1.0
# ----- Generating with seed: "no one needs "rights"
# any longer); at on"
# no one needs "rights"
# any longer); at one upon himself isness vigible! he wher. "knows thence its himself
# it every sublimoed a firmed that the only comparipriwer of the senlig of and my such also it which
# end; i so home
# only burbhe sicknomans egoordime. it would be thanly
# "cre vanity, by a raons, we of roun accurious reverence of life an truths. the mirhapture presern my trust loves which atquile world-man, our scruth eumonity and prili
# ----- diversity: 1.2
# ----- Generating with seed: "no one needs "rights"
# any longer); at on"
# no one needs "rights"
# any longer); at only of
# gever. poull--thus loft to much that that o.--what
# expedit under itsula of necessarily of
# alours of the alkoring manishoms? order besequasigion of the knowledgehs's we whis aba helond, the
# dats it that the hi develve. which this final to alad dremal ayterline,
# is by livinguit; and ars, miking to doubsiesi kod me.=jugg who destructions. for series of clast other to
# tuare a carry the indiriled
# Epoch 8/60
# 130816/200285 [==================>...........] - ETA: 1:06 - loss: 1.4113
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-b3118cc0b3d8> in <module>()
#     109           batch_size=128,
#     110           epochs=60,
# --> 111           callbacks=[print_callback])
#
# /home/krohak/anaconda3/lib/python3.6/site-packages/keras/models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1000                               initial_epoch=initial_epoch,
#    1001                               steps_per_epoch=steps_per_epoch,
# -> 1002                               validation_steps=validation_steps)
#    1003
#    1004     def evaluate(self, x=None, y=None,
#
# /home/krohak/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# /home/krohak/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1234                         ins_batch[i] = ins_batch[i].toarray()
#    1235
# -> 1236                     outs = f(ins_batch)
#    1237                     if not isinstance(outs, list):
#    1238                         outs = [outs]
#
# /home/krohak/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2480         session = get_session()
#    2481         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2482                               **self.session_kwargs)
#    2483         return updated[:len(self.outputs)]
#    2484
#
# /home/krohak/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/krohak/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# /home/krohak/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /home/krohak/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# /home/krohak/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# /home/krohak/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:
